# %%
from pathlib import Path

DATA_DIR = Path("../data/plant_disease")

print("Dataset exists:", DATA_DIR.exists())
print("Dataset path:", DATA_DIR.resolve())

# %%
from pathlib import Path

DATA_DIR = Path("../data/plant_disease")

classes = [
    folder.name
    for folder in DATA_DIR.iterdir()
    if folder.is_dir()
]

print("Number of disease classes:", len(classes))

for i, name in enumerate(classes, start=1):
    print(i, name)

# %%
from pathlib import Path

DATA_DIR = Path("../data/plant_disease")

print("Folders directly inside plant_disease:\n")

for folder in DATA_DIR.iterdir():
    if folder.is_dir():
        print("📁", folder.name)

# %%
from pathlib import Path

DATA_DIR = Path("../data/plant_disease")

for folder in DATA_DIR.rglob("*"):
    if folder.is_dir():
        print(folder)

# %%
DATA_DIR = Path("../data/plant_disease")

# %%
DATA_DIR = Path("../data/plant_disease/PlantVillage/train")

# %%
from pathlib import Path

base = Path("../data/plant_disease/PlantVillage")

for folder in base.rglob("*"):
    if folder.is_dir():
        print(folder)

# %%
from pathlib import Path

DATA_DIR = Path("../data/plant_disease")

classes = [
    folder.name
    for folder in DATA_DIR.iterdir()
    if folder.is_dir()
]

print("Number of disease classes:", len(classes))

for i, name in enumerate(sorted(classes), start=1):
    print(i, name)

# %%
pip install tensorflow

# %%
import tensorflow as tf

print("TensorFlow version:", tf.__version__)

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

print("Image size:", IMG_SIZE)
print("Batch size:", BATCH_SIZE)

# %%
from pathlib import Path

DATA_DIR = Path(r"C:\Users\jahna\OneDrive\Desktop\python\plant_disease\PlantVillage")

print("DATA_DIR:", DATA_DIR)
print("Exists:", DATA_DIR.exists())

# %%
import tensorflow as tf

train_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=(224, 224),
    batch_size=32
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=(224, 224),
    batch_size=32
)

# %%
class_names = train_ds.class_names

print("Number of classes:", len(class_names))
print("\nClasses:")
for i, name in enumerate(class_names):
    print(i, name)

# %%
from pathlib import Path

DATA_DIR = Path(r"C:\Users\jahna\OneDrive\Desktop\python\plant_disease\PlantVillage")

print("Direct folders:")
for folder in DATA_DIR.iterdir():
    if folder.is_dir():
        print("📁", folder.name)

# %%
from pathlib import Path

for folder in DATA_DIR.rglob("*"):
    if folder.is_dir():
        images = list(folder.glob("*.jpg")) + list(folder.glob("*.JPG")) + list(folder.glob("*.jpeg")) + list(folder.glob("*.png"))
        
        if images:
            print(folder)

# %%
DATA_DIR = Path(r"C:\Users\jahna\OneDrive\Desktop\python\plant_disease\PlantVillage\train")

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=(224, 224),
    batch_size=32
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=(224, 224),
    batch_size=32
)

print("Classes:", len(train_ds.class_names))

# %%
import tensorflow as tf
from pathlib import Path

DATA_DIR = Path(
    r"C:\Users\jahna\OneDrive\Desktop\python\plant_disease\PlantVillage\train"
)

train_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=(224, 224),
    batch_size=32
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=(224, 224),
    batch_size=32
)

class_names = train_ds.class_names

print("Number of classes:", len(class_names))
print(class_names)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

print("Dataset preparation completed.")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

plt.tight_layout()
plt.show()

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from pathlib import Path

DATA_DIR = Path(
    r"C:\Users\jahna\OneDrive\Desktop\python\plant_disease\PlantVillage\train"
)

IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 42

train_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    validation_split=0.2,
    subset="training",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    validation_split=0.2,
    subset="validation",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

class_names = train_ds.class_names
NUM_CLASSES = len(class_names)

print("Number of classes:", NUM_CLASSES)
print("Classes:")
for i, name in enumerate(class_names):
    print(i, name)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(
    buffer_size=AUTOTUNE
)

val_ds = val_ds.cache().prefetch(
    buffer_size=AUTOTUNE
)

# %%
train_ds = train_ds.shuffle(1000).prefetch(AUTOTUNE)
val_ds = val_ds.prefetch(AUTOTUNE)

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2

base_model = MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights="imagenet"
)

# Freeze pretrained layers initially
base_model.trainable = False

model = models.Sequential([
    layers.Input(shape=(224, 224, 3)),

    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),

    layers.Rescaling(1./127.5, offset=-1),

    base_model,

    layers.GlobalAveragePooling2D(),

    layers.Dropout(0.3),

    layers.Dense(128, activation="relu"),

    layers.Dropout(0.2),

    layers.Dense(NUM_CLASSES, activation="softmax")
])

model.summary()

# %%
layers.Dense(NUM_CLASSES, activation="softmax")

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
import tensorflow as tf

print("TensorFlow version:", tf.__version__)
print("GPU devices:", tf.config.list_physical_devices("GPU"))

# %%
import tensorflow as tf

print(tf.__version__)
print(tf.config.list_physical_devices())
print(tf.config.list_physical_devices("GPU"))
# Out:
# 2.21.0
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# []

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=2,
    callbacks=callbacks
)

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=3,
        restore_best_weights=True
    ),

    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.2,
        patience=2,
        min_lr=1e-7
    ),

    tf.keras.callbacks.ModelCheckpoint(
        "plant_disease_mobilenetv2_best.keras",
        monitor="val_accuracy",
        save_best_only=True
    )
]

print("Callbacks defined successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 callbacks = [
# ----> 2     tf.keras.callbacks.EarlyStopping(
#       3         monitor="val_loss",
#       4         patience=3,
#       5         restore_best_weights=True
#
# NameError: name 'tf' is not defined

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=2,
    callbacks=callbacks
)
